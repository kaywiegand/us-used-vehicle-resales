# %% [markdown]
# | Workflow              | 01_exploration                  | 02_preprocessing                          | 03_modeling                         | 04_evaluation                     |
# |:-----------------------|:--------------------------------|:-------------------------------------------|:------------------------------------|:-----------------------------------|
# |                       | Project Introduction & Context   | Data Splitting & Export                   |  Baseline Model Definition             |       Test Data Evaluation                             |
# |                       |Metric Definition                | Data Cleaning                             | Model Training                         | Model Interpretation               |
# |                       |Data Acquisition                  | Data Filtering                            |  Hyperparameter Tuning                   |  Error Analysis           |
# |                       | Exploratory Data Analysis       | Outlier Handling                          | Master Pipeline Definition           |  Feature Importance Analysis                     |
# |                       |Outlier Detection (Train Data)   | Data Distribution Adjustment              |Validation Strategy                   |  Residual Analysis      |
# |                       | Key Findings & Hypotheses       | Feature Engineering                       | Prediction Generation (Inference)                |  Business Interpretation               |
# |                       |                                 | Feature Scaling & Normalization         | Final Pipeline Export              |   Prediction Usability Assessment         |
# |                       |                                    | Feature Reduction                         |                       |   |
# |                       |                                | Feature Selection                         |                                    |                                   |
# |                       |                                |                                           |                                    |                                   |
# | **StackFuel Way**     |                                |                                           |                                    |                                   |
# | Preparation           | ✔                              |                                           |                                    |                                   |
# | EDA                   | ✔                              |                                           |                                    |                                   |
# | Split                 |                                | ✔                                         |                                    |                                   |
# | Data Preparation      |                                | ✔                                         |                                    |                                   |
# | Modeling              |                                |                                           | ✔                                  |                                   |
# | Model Interpretation  |                                |                                           |                                    | ✔                                 |
# | Storytelling          |                                |                                           |                                    | ✔                                 |
# |                       |                                |                                           |                                    |                                   |
# | **CRISP-DM**          |                                |                                           |                                    |                                   |
# | Business Understanding| ✔                              |                                           |                                    |                                   |
# | Data Understanding    | ✔                              |                                           |                                    |                                   |
# | Data Preparation      |                                | ✔                                         |                                    |                                   |
# | Modeling              |                                |                                           | ✔                                  |                                   |
# | Evaluation            |                                |                                           | ✔                                  | ✔                                 |
# | Deployment Preparation|                                |                                           | ✔                                  |                                   |
# | Business Evaluation   |                                |                                           |                                    | ✔                                 |

# %% [markdown]
# # Workflow

# %% [markdown]
# ## 01_exploration
#
# * Introduce Project Context
# * Define Metrics
# * Gather Data
# * Split Data & Export Datasets
# * Perform Exploratory Data Analysis
# * Detect Outliers (Train Data)
# * Summarize Key Findings & Hypotheses
#
# ---
#
# ## 02_preprocessing
#
# - Clean Data (Handle Missing Values, Ensure Data Hygiene)
# - Filter Data (Apply Plausibility Checks & Constraints)
# - Handle Outliers
# - Adjust Data Distribution (Perform Re-/Sampling)
# - Engineer Features (Create Transformations & Interactions)
# - Scale & Normalize Features
# - Apply Dimensionality Reduction
# - Perform Feature Selection
#
# ---
#
# ## 03_modeling
#
# * Define Baseline Model
# * Train Models
# * Tune Hyperparameters
# * Build Master Pipeline
# * Apply Validation Strategy
# * Perform Inference / Generate Predictions
# * Export Final Pipeline
#
# ---
#
# ## 04_evaluation
#
# * Evaluate on Test Data
# * Interpret Model
# * Perform Error Analysis
# * Analyze Feature Importance
# * Conduct Residual Analysis
# * Interpret Business Impact
# * Assess Prediction Usability

# %% [markdown]
# # Nomenstil - corporate / reporting ready

# %% [markdown]
# ## 01_exploration
#
# * Project Introduction & Context
# * Metric Definition
# * Data Acquisition
# * Data Splitting & Export
# * Exploratory Data Analysis
# * Outlier Detection (Train Data)
# * Key Findings & Hypotheses
#
# ---
#
# ## 02_preprocessing
#
# * Data Cleaning (Missing Values, Data Hygiene)
# * Data Filtering (Plausibility Checks & Constraints)
# * Outlier Handling
# * Data Distribution Adjustment (Re-/Sampling)
# * Feature Engineering (Transformations, Interactions)
# * Feature Scaling & Normalization
# * Feature Reduction
# * Feature Selection
#
# ---
#
# ## 03_modeling
#
# * Baseline Model Definition
# * Model Training
# * Hyperparameter Tuning
# * Master Pipeline Definition
# * Validation Strategy
# * Inference / Prediction Generation
# * Final Pipeline Export
#
# ---
#
# ## 04_evaluation
#
# * Test Data Evaluation
# * Model Interpretation
# * Error Analysis
# * Feature Importance Analysis
# * Residual Analysis
# * Business Interpretation
# * Prediction Usability Assessment

# %% [markdown]
# # CRISP-DM aligned - professionell

# %% [markdown]
# ## 🟦 01_exploration *(Business + Data Understanding)*
#
# * Introduce Project Context
# * Define Metrics
# * Gather Data
# * Perform Exploratory Data Analysis
# * Detect Outliers (Train Perspective)
# * Summarize Key Findings & Hypotheses
#
# ---
#
# ## 🟦 02_preprocessing *(Data Preparation)*
#
# * Split Data into Train / Validation / Test Sets
# * Export Data Splits
# * Clean & Filter Data
# * Handle Outliers
# * Perform Data Re-/Sampling
# * Engineer Features
#
# ---
#
# ## 🟦 03_modeling *(Modeling)*
#
# * Define Baseline Model
# * Train Models
# * Tune Hyperparameters
# * Apply Validation Strategy
# * Build Master Pipeline
# * Export Final Pipeline
#
# ---
#
# ## 🟦 04_evaluation *(Evaluation)*
#
# * Evaluate on Test Data
# * Generate Predictions (Inference)
# * Perform Error Analysis
# * Conduct Residual Analysis
# * Analyze Feature Importance
# * Interpret Model Behavior
# * Interpret Business Impact
# * Assess Prediction Usability
#
# ---

# %%
 #
